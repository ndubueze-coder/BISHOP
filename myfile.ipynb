# %%
print("hello, world")
# Out:
# hello, world

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r'healthcare_data.csv')
df.head()
# Out:
#       Sex    State History of Sugar Level in Family  Age  Glucose Sugar Level  \
# 0    Male     Abia                              Yes   33                107.0
# 1  Female    Enugu                              Yes   36                115.2
# 2    Male  Katsina                              Yes   47                107.9
# 3    Male     Kano                              Yes   58                 96.1
# 4    Male   Kaduna                               No   33                 74.8
#
#     BMI
# 0  20.3
# 1  24.3
# 2  27.7
# 3  31.1
# 4  26.4

# %% [markdown]
# comparative analysis: tabel graph virtualization

# %%
plt.hist(x = df["Sex"], bins=10, edgecolor="blue", facecolor='black')
plt.gca().set_facecolor("yellow")

# %%
pd.pivot_table(df, index= "State", values= ['Glucose Sugar Level', "BMI"],
              aggfunc= "mean").plot(kind= "pie", subplots= True, legend= False, figsize=(15,6))
# Out:
# array([<Axes: ylabel='BMI'>, <Axes: ylabel='Glucose Sugar Level'>],
#       dtype=object)
